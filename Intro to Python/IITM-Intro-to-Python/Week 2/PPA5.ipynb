# %% [markdown]
# Write a program to realize the equation of a line given 2 points (x_1,y_1)(x
# 1
# ​
#  ,y
# 1
# ​
#  ) and (x_2,y_2)(x
# 2
# ​
#  ,y
# 2
# ​
#  ) in 2D space. The input is in 5 lines where, the first, second, third, and fourth lines represent x_1x
# 1
# ​
#  , y_1y
# 1
# ​
#  , x_2x
# 2
# ​
#  , and y_2y
# 2
# ​
#   respectively. The fifth line corresponds to x_3x
# 3
# ​
#  . Determine y_3y
# 3
# ​
#   using the equation of a straight line as given below:
#
# \cfrac{x-x_1}{x_2-x_1} = \cfrac{y-y_1}{y_2-y_1}
# x
# 2
# ​
#  −x
# 1
# ​
#
# x−x
# 1
# ​
#
# ​
#  =
# y
# 2
# ​
#  −y
# 1
# ​
#
# y−y
# 1
# ​
#
# ​
#
# The output should be "Vertical Line" if the line is vertical. In other cases, the output should be 2 lined, where the first line is the value of y_3y
# 3
# ​
#   and the second line indicates whether the slope of the line is positive, negative or zero. Print "Positive Slope", "Negative Slope" or "Horizontal Line" accordingly.
#
# Note that all inputs are to be processed as real numbers.

# %%
x1 = float(input())
y1 = float(input())
x2 = float(input())
y2 = float(input())
x3 = float(input())

slope = 0.0
if (x2 == x1):
    slope = 1
else:
    slope = ( (y2-y1) / (x2-x1) )
    y3 = ( ( (x3-x1) * (y2-y1) / (x2-x1) ) + y1)

if (slope == 1):
    print("Vertical Line")
else:
    print(y3)
    if (slope > 0):
        print("Positive Slope")
    elif (slope < 0):
        print("Negative Slope")
    else:
        print("Horizontal Line")
